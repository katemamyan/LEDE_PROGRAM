# %%
pip install netCDF4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 4.7 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [netCDF4]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas
import netCDF4 as nc

# %%
coral = nc.Dataset("/Users/katemamyan/Desktop/Lede/Veronica classes/Lesson_4_07-24-working-with-netcdf-datasets/coral_reef_data/ct5km_dhw_v3.1_20250702.nc")

# %%
coral
# Out:
# <class 'netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     acknowledgement: NOAA Coral Reef Watch Program
#     cdm_data_type: Grid
#     comment: This is a product of the NOAA Coral Reef Watch Daily Global 5km Satellite Coral Bleaching Heat Stress Monitoring Product Suite Version 3.1.
#     contributor_name: NOAA Coral Reef Watch Program
#     contributor_role: Collecting source data and deriving products; performing quality control of products; disseminating, storing, and submitting data to archive
#     Conventions: CF-1.6, ACDD-1.3
#     creator_email: coralreefwatch@noaa.gov
#     creator_institution: NOAA/NESDIS/STAR Coral Reef Watch Program
#     creator_name: NOAA Coral Reef Watch Program
#     creator_type: group
#     creator_url: https://coralreefwatch.noaa.gov/
#     date_created: 20180301T120000Z
#     date_issued: 20250703T142406Z
#     date_metadata_modified: 20201118T120000Z
#     date_modified: 20180301T120000Z
# ...

# %%
coral.data_model
# Out:
# 'NETCDF4'

# %%
# look at your variables
coral.variables
# Out:
# {'time': <class 'netCDF4.Variable'>
#  int32 time(time)
#      axis: T
#      coverage_content_type: coordinate
#      long_name: reference time of the data
#      standard_name: time
#      units: seconds since 1981-01-01 00:00:00
#  unlimited dimensions: time
#  current shape = (1,)
#  filling on, default _FillValue of -2147483647 used,
#  'lat': <class 'netCDF4.Variable'>
#  float32 lat(lat)
#      axis: Y
#      comment: equirectangular projection and grid centers
#      coverage_content_type: coordinate
#      long_name: latitude
#      standard_name: latitude
#      units: degrees_north
#      valid_max: 89.975
#      valid_min: -89.975
#  unlimited dimensions:
#  current shape = (3600,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'lon': <class 'netCDF4.Variable'>
#  float32 lon(lon)
#      axis: X
#      comment: equirectangular projection and grid centers
#      coverage_content_type: coordinate
#      long_name: longitude
# ...

# %%
coral.variables['time']
# Out:
# <class 'netCDF4.Variable'>
# int32 time(time)
#     axis: T
#     coverage_content_type: coordinate
#     long_name: reference time of the data
#     standard_name: time
#     units: seconds since 1981-01-01 00:00:00
# unlimited dimensions: time
# current shape = (1,)
# filling on, default _FillValue of -2147483647 used

# %%
# find seconds since 1981
coral.variables['time'][0].data
# Out:
# array(1404302400, dtype=int32)

# %%
# figure out days since Jan 1, 1981
seconds_per_day = 60*60*24
seconds_per_day
# Out:
# 86400

# %%
1404302400/seconds_per_day
# Out:
# 16253.5

# %%
from datetime import date
start_date = date(1981, 1, 1) # format is year, month day
end_date = date(2025, 7, 2) 
delta = end_date - start_date
delta.days
# Out:
# 16253

# %%
from datetime import timedelta
timedelta(delta.days).total_seconds()
# Out:
# 1404259200.0

# %%
timedelta(delta.days).total_seconds() - 1404302400
# Out:
# -43200.0

# %%
# look at values in degree heating weeks
coral.variables['degree_heating_week'][:].min()
# Out:
# np.float64(0.0)

# %%
# find max value
coral.variables['degree_heating_week'][:].max()
# Out:
# np.float64(59.870000000000005)
