# %%
import pandas as pd

# %%
# openning file with data
df = pd.read_csv('/Users/katemamyan/Documents/GitHub/LEDE_PROGRAM/project_01/archive_data.csv', index_col=False)
df.head()
# Out:
#                                                 link  \
# 0  https://www.1tv.am/hy/video/Հարցազրույց-Սոսի-Թ...
# 1  https://www.1tv.am/hy/video/Հարցազրույց-Համբիկ...
# 2  https://www.1tv.am/hy/video/Հարցազրույց-Կայա-Կ...
# 3  https://www.1tv.am/hy/video/Հարցազրույց-Արթուր...
# 4  https://www.1tv.am/hy/video/Հարցազրույց-Էլեն-Հ...
#
#                                           video_link  \
# 0  https://www.youtube.com/embed/gkLMht3Vt-k?auto...
# 1  https://www.youtube.com/embed/yjj8ISwxTwE?auto...
# 2  https://www.youtube.com/embed/Hd6l_IRhygI?auto...
# 3  https://www.youtube.com/embed/d5x7uI6cCLI?auto...
# 4  https://www.youtube.com/embed/gpIDqXFZx8o?auto...
#
#                               title   time          date
# 0    Հարցազրույց Սոսի Թաթիկյանի հետ  22:10  03 Հլս, 2025
# 1  Հարցազրույց Համբիկ Սարաֆյանի հետ  22:10  02 Հլս, 2025
# 2       Հարցազրույց Կայա Կալասի հետ  22:10  01 Հլս, 2025
# 3  Հարցազրույց Արթուր Պողոսյանի հետ  22:10  30 Հնս, 2025
# 4    Հարցազրույց Էլեն Հոխիկյանի հետ  22:30  27 Հնս, 2025

# %%
# cleaning the date column, removing armenian abbreviations and converting to the date format


# armenian month abbreviations to month numbers
armenian_months = {
    'Հնվ': '01', 'Փտր': '02', 'Մար': '03', 'Ապր': '04', 'Մայ': '05', 'Հնս': '06',
    'Հլս': '07', 'Օգս': '08', 'Սեպ': '09', 'Հոկ': '10', 'Նմբ': '11', 'Դեկ': '12'
}

# Split and map months
df['day'] = df['date'].str.extract(r'(\d{2})')
df['arm_month'] = df['date'].str.extract(r'(\w{3})')
df['year'] = df['date'].str.extract(r'(\d{4})')

df['month'] = df['arm_month'].map(armenian_months)

# Combine into ISO format date
df['iso_date'] = pd.to_datetime(df['year'] + '-' + df['month'] + '-' + df['day'])

print(df[['date', 'iso_date']])
# Out:
#               date   iso_date
# 0     03 Հլս, 2025 2025-07-03
# 1     02 Հլս, 2025 2025-07-02
# 2     01 Հլս, 2025 2025-07-01
# 3     30 Հնս, 2025 2025-06-30
# 4     27 Հնս, 2025 2025-06-27
# ...            ...        ...
# 1270  06 Փտր, 2020 2020-02-06
# 1271  05 Փտր, 2020 2020-02-05
# 1272  04 Փտր, 2020 2020-02-04
# 1273  03 Փտր, 2020 2020-02-03
# 1274  12 Հոկ, 2021 2021-10-12
#
# [1275 rows x 2 columns]

# %%
df
# Out:
#                                                    link  \
# 0     https://www.1tv.am/hy/video/Հարցազրույց-Սոսի-Թ...
# 1     https://www.1tv.am/hy/video/Հարցազրույց-Համբիկ...
# 2     https://www.1tv.am/hy/video/Հարցազրույց-Կայա-Կ...
# 3     https://www.1tv.am/hy/video/Հարցազրույց-Արթուր...
# 4     https://www.1tv.am/hy/video/Հարցազրույց-Էլեն-Հ...
# ...                                                 ...
# 1270  https://www.1tv.am/hy/video/Հարցազրույց-Պետրոս...
# 1271  https://www.1tv.am/hy/video/Հարցազրույց-Պետրոս...
# 1272  https://www.1tv.am/hy/video/Հարցազրույց-Պետրոս...
# 1273  https://www.1tv.am/hy/video/Հարցազրույց-Պետրոս...
# 1274  https://www.1tv.am/hy/video/Հարցազրույց-Արսեն-...
#
#                                              video_link  \
# 0     https://www.youtube.com/embed/gkLMht3Vt-k?auto...
# 1     https://www.youtube.com/embed/yjj8ISwxTwE?auto...
# 2     https://www.youtube.com/embed/Hd6l_IRhygI?auto...
# 3     https://www.youtube.com/embed/d5x7uI6cCLI?auto...
# 4     https://www.youtube.com/embed/gpIDqXFZx8o?auto...
# ...                                                 ...
# 1270  https://www.youtube.com/embed/6g5sFkYDopo?auto...
# 1271  https://www.youtube.com/embed/g_N7y10q5jE?auto...
# 1272  https://www.youtube.com/embed/PLfaKqneN8g?auto...
# 1273  https://www.youtube.com/embed/XA3jcUzjQRI?auto...
# 1274  https://www.youtube.com/embed/Mo-CuhQ4wNg?auto...
#
#                                                   title   time          date  \
# 0                        Հարցազրույց Սոսի Թաթիկյանի հետ  22:10  03 Հլս, 2025
# 1                      Հարցազրույց Համբիկ Սարաֆյանի հետ  22:10  02 Հլս, 2025
# 2                           Հարցազրույց Կայա Կալասի հետ  22:10  01 Հլս, 2025
# 3                      Հարցազրույց Արթուր Պողոսյանի հետ  22:10  30 Հնս, 2025
# 4                        Հարցազրույց Էլեն Հոխիկյանի հետ  22:30  27 Հնս, 2025
# ...                                                 ...    ...           ...
# 1270  Հարցազրույց Պետրոս Ղազարյանի հետ. Կարեն Անդրեա...  19:30  06 Փտր, 2020
# 1271  Հարցազրույց Պետրոս Ղազարյանի հետ. Էդմոն Մարուքյան  19:30  05 Փտր, 2020
# 1272  Հարցազրույց Պետրոս Ղազարյանի հետ. Տիգրան Խաչատ...  19:30  04 Փտր, 2020
# 1273  Հարցազրույց Պետրոս Ղազարյանի հետ. Ռուբեն Ռուբի...  19:30  03 Փտր, 2020
# 1274                    Հարցազրույց Արսեն Թորոսյանի հետ  18:24  12 Հոկ, 2021
#
#      day arm_month  year month   iso_date
# 0     03       Հլս  2025    07 2025-07-03
# 1     02       Հլս  2025    07 2025-07-02
# 2     01       Հլս  2025    07 2025-07-01
# 3     30       Հնս  2025    06 2025-06-30
# 4     27       Հնս  2025    06 2025-06-27
# ...   ..       ...   ...   ...        ...
# 1270  06       Փտր  2020    02 2020-02-06
# 1271  05       Փտր  2020    02 2020-02-05
# 1272  04       Փտր  2020    02 2020-02-04
# 1273  03       Փտր  2020    02 2020-02-03
# 1274  12       Հոկ  2021    10 2021-10-12
#
# [1275 rows x 10 columns]

# %%
# creating new 'cleaned_title' column where we are cleaning names to keep only the name of the guest

df['cleaned_title'] = (
    df['title']
    .str.replace(
        r'Հարցազրույց Պետրոս Ղազարյանի հետ.|Հարցազրույց|հետ|Պետրոս Ղազարյանի հարցազրույցը|ՀՀ Ազգային ժողովի նախագահ|ՀՀ վարչապետ|փոխվարչապետ',
        '',
        regex=True
    )
    .str.replace(r'ի\b', '', regex=True)
    .str.lower()
    .str.strip()
)

# %%
df.to_csv("cleaned_archive_data.csv", index=False)

# %%
df['cleaned_title'].value_counts()
# Out:
# cleaned_title
# էդմոն մարուքյան                    35
# անդրանիկ քոչարյան                  34
# արամ սարգսյան                      31
# հայկ կոնջորյան                     28
# արմեն գրիգորյան                    27
#                                    ..
# վահան քերոբյան և վարդան արամյան     1
# գրիգոր էլիզբարյան                   1
# վիգեն չետերյան                      1
# արման գրիգորյան                     1
# նաիրա զոհրաբյան                     1
# Name: count, Length: 506, dtype: int64

# %%
guests = df.pivot_table(
    index='cleaned_title',   # people as rows
    columns='year',          # years as columns
    values='link',           # any column with data to count
    aggfunc='count',         # count how many times each person appears per year
    fill_value=0             # fill missing combinations with 0
)

# %%
guests = guests.assign(Total=guests.sum(axis=1)).sort_values('Total', ascending=False)

# %%
guests
# Out:
# year                2020  2021  2022  2023  2024  2025  Total
# cleaned_title
# էդմոն մարուքյան        7    10    12     6     0     0     35
# անդրանիկ քոչարյան      7     8     4     6     6     3     34
# արամ սարգսյան          5     7     6     6     5     2     31
# հայկ կոնջորյան         2     6     8     4     3     5     28
# արմեն գրիգորյան        3    10     5     5     4     0     27
# ...                  ...   ...   ...   ...   ...   ...    ...
# ժաննա անդրեասյան       0     0     0     1     0     0      1
# թագուհ թովմասյան       0     0     1     0     0     0      1
# էսթեր դեմիրճյան        1     0     0     0     0     0      1
# էնրիկո դելլա կասայ     0     0     0     0     0     1      1
# ֆրենկ փալոուն          0     0     1     0     0     0      1
#
# [506 rows x 7 columns]

# %%
df[(df['year'] == "2023") & (df["cleaned_title"] == "Էդմոն Մարուքյան")]
# Out:
# Empty DataFrame
# Columns: [link, video_link, title, time, date, day, arm_month, year, month, iso_date, cleaned_title]
# Index: []
