# %% [markdown]
# ## PART ONE: Weather API
#
#
# Register for an account at weatherapi.com
#
# 1. What is the URL to the documentation? <br>
# [Documentation](https://www.weatherapi.com/docs/)
#
#
# 3. Print out the country this location is in.
# 4. Print out the difference between the current temperature and how warm it feels. <br>
# > Use "It feels . ___ degrees colder" or "It feels ___ degrees warmer," not negative numbers.
# 5. What's the current temperature at Heathrow International Airport? Use the airport's IATA code to search.
# 6. What URL would I use to request a 3-day forecast at Heathrow?
# 7. Print the date of each of the 3 days you're getting a forecast for.
# 8. Print the maximum temperature of each of the days.
# 9. Print only the day with the highest maximum temperature.

# %%
import requests
from pprint import pprint
import os
from dotenv import load_dotenv

load_dotenv()  # Loads the .env file

# Correct usage
print(os.getenv("API_KEY"))
# Out:
# c87bef147bed4ce097973242222306

# %%
API_KEY = os.getenv("API_KEY")
base_url = "http://api.weatherapi.com/v1"

# %%
url = f"{base_url}/current.json?key={API_KEY}&q=yerevan"

# %%
r = requests.get(url)

# %%
pprint(r.text)
# Out:
# ('{"location":{"name":"Yerevan","region":"Yerevan","country":"Armenia","lat":40.1811,"lon":44.5136,"tz_id":"Asia/Yerevan","localtime_epoch":1750434954,"localtime":"2025-06-20 '
#  '19:55"},"current":{"last_updated_epoch":1750434300,"last_updated":"2025-06-20 '
#  '19:45","temp_c":32.1,"temp_f":89.8,"is_day":1,"condition":{"text":"Sunny","icon":"//cdn.weatherapi.com/weather/64x64/day/113.png","code":1000},"wind_mph":2.2,"wind_kph":3.6,"wind_degree":299,"wind_dir":"WNW","pressure_mb":1007.0,"pressure_in":29.74,"precip_mm":0.0,"precip_in":0.0,"humidity":14,"cloud":25,"feelslike_c":30.9,"feelslike_f":87.6,"windchill_c":29.1,"windchill_f":84.4,"heatindex_c":27.7,"heatindex_f":81.9,"dewpoint_c":8.4,"dewpoint_f":47.0,"vis_km":10.0,"vis_miles":6.0,"uv":0.5,"gust_mph":6.7,"gust_kph":10.8}}')
